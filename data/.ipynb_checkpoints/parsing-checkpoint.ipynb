# %%
import pandas as pd
import numpy as np
import random
import secrets
from datetime import datetime

file_path = "raw_sleep.csv"
df = pd.read_csv(file_path)

# %%
# Calculating epoch time
df['start'] = pd.to_datetime(df['start'])
df['end'] = pd.to_datetime(df['end'])

# Convert datetime objects to epoch time
df['start_epoch'] = df['start'].astype(int) // 10**9
df['end_epoch'] = df['end'].astype(int) // 10**9
df["duration"] = df['end_epoch'] - df['start_epoch']

# %%
duration_sum = df.groupby('stage')['duration'].sum()
duration_sum
# Out:
# stage
# ASLEEP_UNSPECIFIED     6058430
# AWAKE                  1109461
# DEEP                   1893397
# IN_BED                45096286
# LIGHT                  8998306
# REM                    2888624
# Name: duration, dtype: int64

# %%
# Grouping by date
df['start'] = pd.to_datetime(df['start'])
# df['start_date'] = df['start'].dt.date
df['start_date'] = pd.to_datetime(df['start'])

# Extract year and month and replace the "start" column with it
# df['start_date'] = df['start_date'].dt.to_period('M')
df['start_date'] = df['start_date'].dt.to_period('M')

# Pivoting table into relevant format
grouped = df.groupby(['start_date', 'stage'])['duration'].sum().reset_index()
pivot_df = df.pivot_table(index='start_date', columns='stage', values='duration', aggfunc='sum').reset_index()

# Cleaning data
pivot_df = pivot_df.drop(['ASLEEP_UNSPECIFIED', 'IN_BED', 'AWAKE'], axis=1).dropna()

pivot_df["SUM"] = pivot_df["DEEP"] + pivot_df["LIGHT"] + pivot_df["REM"]

pivot_df["DEEP"] = pivot_df["DEEP"] / pivot_df["SUM"]
pivot_df["LIGHT"] = pivot_df["LIGHT"] / pivot_df["SUM"]
pivot_df["REM"] = pivot_df["REM"] / pivot_df["SUM"]

pivot_df
# TODO: draw a bar graph that compares this to average
# Out:
# /tmp/ipykernel_352/427191653.py:8: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['start_date'] = df['start_date'].dt.to_period('M')
# stage start_date      DEEP     LIGHT       REM       SUM
# 5        2022-01  0.153061  0.639945  0.206994  641680.0
# 6        2022-02  0.156385  0.625328  0.218287  762835.0
# 7        2022-03  0.145993  0.644796  0.209211  697998.0
# 8        2022-04  0.167148  0.627316  0.205536  698248.0
# 9        2022-05  0.147780  0.639686  0.212534  860028.0
# 10       2022-06  0.155186  0.631926  0.212888  864082.0
# 11       2022-07  0.163264  0.600075  0.236661  427535.0
# 12       2022-08  0.169421  0.607467  0.223112  516655.0
# 13       2022-09  0.153312  0.626607  0.220081  707311.0
# 14       2022-10  0.160142  0.633520  0.206338  635603.0
# 15       2022-11  0.152311  0.633206  0.214483  526036.0
# 16       2022-12  0.144651  0.647660  0.207689  340682.0
# 17       2023-01  0.138809  0.659243  0.201949  368752.0
# 18       2023-02  0.144404  0.627372  0.228224  450396.0
# 19       2023-03  0.176989  0.617675  0.205336  403421.0
# 24       2023-08  0.107663  0.673478  0.218859  470896.0
# 25       2023-09  0.105742  0.699506  0.194752  506366.0
# 26       2023-10  0.110232  0.678194  0.211574  521609.0
# 27       2023-11  0.127765  0.664995  0.207240  218925.0
# 28       2023-12  0.120265  0.671131  0.208604  727710.0
# 29       2024-01  0.096111  0.701399  0.202490  662918.0
# 30       2024-02  0.089613  0.732807  0.177580  561032.0
# 31       2024-03  0.091941  0.700711  0.207347  769134.0
# 32       2024-04  0.112522  0.697897  0.189582  440475.0

# %%
import matplotlib.pyplot as plt

# Convert start_date to string
pivot_df['start_date'] = pivot_df['start_date'].astype(str)

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(pivot_df['start_date'], pivot_df['DEEP'], marker='o', label='DEEP')
plt.plot(pivot_df['start_date'], pivot_df['LIGHT'], marker='o', label='LIGHT')
plt.plot(pivot_df['start_date'], pivot_df['REM'], marker='o', label='REM')

plt.title('Sleep Stages Over Time')
plt.xlabel('Date')
plt.ylabel('Duration (minutes)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
# sleep_metrics (sleep efficiency)

#1. JOIN the two sleep datasets by session_id so you can get the date for both
# get the (sleep efficiency / sleep latency / deep : light : rem ratio / sleepWakeups) for each day

#2. GET the dataframes for each graph you'll plot

#3. PLOT the graphs in python

#4. GENERATE new .csv files, upload them to firestore

#5. REACT to read data from DynamoDB and display it on the site

#6. CHATBOT to get health info

#7. DESIGN the site to look nicer

# %%
metrics = pd.read_csv("sleep_metrics.csv")
raw = pd.read_csv("raw_sleep.csv")


metrics = metrics.dropna()
metrics
# Out:
#                sleep_metric                               user_id  \
# 0       percentageSleepDeep  94155c17-864d-46ee-be22-775137bd1cee
# 1        percentageSleepRem  94155c17-864d-46ee-be22-775137bd1cee
# 2      percentageSleepLight  94155c17-864d-46ee-be22-775137bd1cee
# 3      percentageNightAwake  94155c17-864d-46ee-be22-775137bd1cee
# 4       percentageNightDeep  94155c17-864d-46ee-be22-775137bd1cee
# ...                     ...                                   ...
# 11511  percentageSleepLight  94155c17-864d-46ee-be22-775137bd1cee
# 11512  percentageNightAwake  94155c17-864d-46ee-be22-775137bd1cee
# 11513   percentageNightDeep  94155c17-864d-46ee-be22-775137bd1cee
# 11514    percentageNightRem  94155c17-864d-46ee-be22-775137bd1cee
# 11515  percentageNightLight  94155c17-864d-46ee-be22-775137bd1cee
#
#                            sleep_session_id  value
# 0      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca  10.87
# 1      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca  16.94
# 2      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca  70.45
# 3      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca   5.61
# 4      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca  10.44
# ...                                     ...    ...
# 11511  3ed82279-446c-4c72-a6dc-35df4757b571  60.65
# 11512  3ed82279-446c-4c72-a6dc-35df4757b571  11.81
# 11513  3ed82279-446c-4c72-a6dc-35df4757b571  12.22
# 11514  3ed82279-446c-4c72-a6dc-35df4757b571  20.31
# 11515  3ed82279-446c-4c72-a6dc-35df4757b571  55.66
#
# [11516 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import random
import secrets
from datetime import datetime
import matplotlib.pyplot as plt

# Loading in data
metrics = pd.read_csv("sleep_metrics.csv")
raw = pd.read_csv("raw_sleep.csv")

metrics
# Out:
#                sleep_metric                               user_id  \
# 0       percentageSleepDeep  94155c17-864d-46ee-be22-775137bd1cee
# 1        percentageSleepRem  94155c17-864d-46ee-be22-775137bd1cee
# 2      percentageSleepLight  94155c17-864d-46ee-be22-775137bd1cee
# 3      percentageNightAwake  94155c17-864d-46ee-be22-775137bd1cee
# 4       percentageNightDeep  94155c17-864d-46ee-be22-775137bd1cee
# ...                     ...                                   ...
# 11511  percentageSleepLight  94155c17-864d-46ee-be22-775137bd1cee
# 11512  percentageNightAwake  94155c17-864d-46ee-be22-775137bd1cee
# 11513   percentageNightDeep  94155c17-864d-46ee-be22-775137bd1cee
# 11514    percentageNightRem  94155c17-864d-46ee-be22-775137bd1cee
# 11515  percentageNightLight  94155c17-864d-46ee-be22-775137bd1cee
#
#                            sleep_session_id  value
# 0      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca  10.87
# 1      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca  16.94
# 2      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca  70.45
# 3      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca   5.61
# 4      1ca68c00-9dad-486e-b8c5-844e9ecdd2ca  10.44
# ...                                     ...    ...
# 11511  3ed82279-446c-4c72-a6dc-35df4757b571  60.65
# 11512  3ed82279-446c-4c72-a6dc-35df4757b571  11.81
# 11513  3ed82279-446c-4c72-a6dc-35df4757b571  12.22
# 11514  3ed82279-446c-4c72-a6dc-35df4757b571  20.31
# 11515  3ed82279-446c-4c72-a6dc-35df4757b571  55.66
#
# [11516 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import random
import secrets
from datetime import datetime
import matplotlib.pyplot as plt

# Loading in data
metrics = pd.read_csv("sleep_metrics.csv")
raw = pd.read_csv("raw_sleep.csv")

# Merging and cleaning
merged = pd.merge(raw, metrics, on='sleep_session_id', how='inner')
merged = merged.drop(['id', 'timezone', 'log_method', 'user_id', 'end', 'stage'], axis=1)
merged['start'] = pd.to_datetime(merged['start'])
merged['start'] = merged['start'].dt.date
merged = merged.dropna().drop_duplicates()


# Pivoting 
df = merged.pivot_table(index='start', columns='sleep_metric', values='value', aggfunc='sum').reset_index().dropna()
df['start'] = pd.to_datetime(df['start'])

# Cut off dates after 2023 because of gap in data
df = df[df['start'] < '2022-11-01']
df
# df
# Out:
# sleep_metric      start  percentageNightAwake  percentageNightDeep  \
# 98           2022-01-09                  7.27                10.61
# 99           2022-01-10                 10.40                16.53
# 100          2022-01-11                 10.97                15.02
# 101          2022-01-12                  9.43                15.92
# 102          2022-01-13                  5.84                11.59
# ..                  ...                   ...                  ...
# 382          2022-10-27                  6.85                13.04
# 383          2022-10-28                  9.38                18.98
# 384          2022-10-29                  6.48                11.50
# 385          2022-10-30                 12.68                12.37
# 386          2022-10-31                 13.62                12.74
#
# sleep_metric  percentageNightLight  percentageNightRem  percentageSleepAwake  \
# 98                           57.88               24.25                  7.39
# 99                           50.10               22.97                 10.60
# 100                          59.93               14.07                 11.16
# 101                          58.65               16.00                  9.56
# 102                          63.57               18.99                  5.86
# ..                             ...                 ...                   ...
# 382                          66.14               13.97                  7.12
# 383                          51.60               20.04                  9.34
# 384                          62.39               19.63                  6.40
# 385                          59.22               15.73                 13.20
# 386                          61.42               12.23                 13.71
#
# sleep_metric  percentageSleepDeep  percentageSleepLight  percentageSleepRem  \
# 98                          10.90                 59.46               24.91
# 99                          17.05                 51.66               23.68
# 100                         15.43                 61.58               14.46
# 101                         16.30                 60.05               16.38
# 102                         11.82                 64.82               19.37
# ..                            ...                   ...                 ...
# 382                         13.69                 69.48               14.68
# 383                         19.11                 51.95               20.18
# 384                         11.50                 62.39               19.63
# 385                         12.94                 61.98               16.46
# 386                         12.94                 62.38               12.42
#
# sleep_metric  sleepEfficiency  sleepLatency  sleepWakeups  timeNightAsleep  \
# 98                  92.733020     14.016666           4.0        489.16666
# 99                  89.604576     14.516666           6.0        430.55000
# 100                 89.028980     17.016666           8.0        568.45000
# 101                 90.567055      3.016667           9.0        503.10000
# 102                 94.156006     10.516666           4.0        515.03330
# ..                        ...           ...           ...              ...
# 382                 93.151350     11.516666           4.0        349.78333
# 383                 90.620155      0.000000           7.0        467.60000
# 384                 93.516630      0.000000           4.0        459.16666
# 385                 87.315704      1.516667           4.0        363.23334
# 386                 86.383160      2.016667           8.0        335.16666
#
# sleep_metric  timeNightAwake  timeNightDeep  timeNightInBed  timeNightLight  \
# 98                     38.33          55.95       527.50000          305.30
# 99                     49.95          79.45       945.05000          240.73
# 100                    70.05          95.90      1009.45000          382.68
# 101                    52.40          88.43      1035.50000          325.78
# 102                    31.97          63.40       916.53333          347.73
# ..                       ...            ...             ...             ...
# 382                    25.72          48.95       835.00000          248.37
# 383                    48.40          97.93       969.08334          266.27
# 384                    31.83          56.45       951.58334          306.32
# 385                    52.77          51.45       416.00000          246.35
# 386                    52.83          49.43       388.00000          238.30
#
# sleep_metric  timeNightRem  timeSleepAwake  wakeupsOver15Minutes
# 98                  127.92           37.95                   0.0
# 99                  110.37           49.42                   0.0
# 100                  89.87           69.38                   2.0
# 101                  88.88           51.87                   0.0
# 102                 103.90           31.45                   0.0
# ..                     ...             ...                   ...
# 382                  52.47           25.45                   0.0
# 383                 103.40           47.88                   0.0
# 384                  96.40           31.43                   0.0
# 385                  65.43           52.45                   2.0
# 386                  47.43           52.38                   0.0
#
# [249 rows x 20 columns]

# %%
# Removes outliers for a specific column
def removeOutliers(dataframe, column):
        # Calculate mean and standard deviation of sleepLatency
        mean_sleep_latency = dataframe[column].mean()
        std_sleep_latency = dataframe[column].std()

        # Define the upper and lower bounds for outliers
        upper_bound = mean_sleep_latency + 1.5 * std_sleep_latency
        lower_bound = mean_sleep_latency - 1.5 * std_sleep_latency

        # Filter the DataFrame to remove outliers
        filtered_df = dataframe[(dataframe[column] <= upper_bound) & (dataframe[column] >= lower_bound)]
        filtered_df.loc[:, 'start'] = pd.to_datetime(filtered_df['start'])
        return filtered_df

    
# columns = df.columns.tolist()[1:]

# for c in columns:
#     df = removeOutliers(df, c)

    
df
# removeOutliers(df, 'sleepLatency')
# Out:
# sleep_metric      start  percentageNightAwake  percentageNightDeep  \
# 98           2022-01-09                  7.27                10.61
# 99           2022-01-10                 10.40                16.53
# 100          2022-01-11                 10.97                15.02
# 101          2022-01-12                  9.43                15.92
# 102          2022-01-13                  5.84                11.59
# ..                  ...                   ...                  ...
# 382          2022-10-27                  6.85                13.04
# 383          2022-10-28                  9.38                18.98
# 384          2022-10-29                  6.48                11.50
# 385          2022-10-30                 12.68                12.37
# 386          2022-10-31                 13.62                12.74
#
# sleep_metric  percentageNightLight  percentageNightRem  percentageSleepAwake  \
# 98                           57.88               24.25                  7.39
# 99                           50.10               22.97                 10.60
# 100                          59.93               14.07                 11.16
# 101                          58.65               16.00                  9.56
# 102                          63.57               18.99                  5.86
# ..                             ...                 ...                   ...
# 382                          66.14               13.97                  7.12
# 383                          51.60               20.04                  9.34
# 384                          62.39               19.63                  6.40
# 385                          59.22               15.73                 13.20
# 386                          61.42               12.23                 13.71
#
# sleep_metric  percentageSleepDeep  percentageSleepLight  percentageSleepRem  \
# 98                          10.90                 59.46               24.91
# 99                          17.05                 51.66               23.68
# 100                         15.43                 61.58               14.46
# 101                         16.30                 60.05               16.38
# 102                         11.82                 64.82               19.37
# ..                            ...                   ...                 ...
# 382                         13.69                 69.48               14.68
# 383                         19.11                 51.95               20.18
# 384                         11.50                 62.39               19.63
# 385                         12.94                 61.98               16.46
# 386                         12.94                 62.38               12.42
#
# sleep_metric  sleepEfficiency  sleepLatency  sleepWakeups  timeNightAsleep  \
# 98                  92.733020     14.016666           4.0        489.16666
# 99                  89.604576     14.516666           6.0        430.55000
# 100                 89.028980     17.016666           8.0        568.45000
# 101                 90.567055      3.016667           9.0        503.10000
# 102                 94.156006     10.516666           4.0        515.03330
# ..                        ...           ...           ...              ...
# 382                 93.151350     11.516666           4.0        349.78333
# 383                 90.620155      0.000000           7.0        467.60000
# 384                 93.516630      0.000000           4.0        459.16666
# 385                 87.315704      1.516667           4.0        363.23334
# 386                 86.383160      2.016667           8.0        335.16666
#
# sleep_metric  timeNightAwake  timeNightDeep  timeNightInBed  timeNightLight  \
# 98                     38.33          55.95       527.50000          305.30
# 99                     49.95          79.45       945.05000          240.73
# 100                    70.05          95.90      1009.45000          382.68
# 101                    52.40          88.43      1035.50000          325.78
# 102                    31.97          63.40       916.53333          347.73
# ..                       ...            ...             ...             ...
# 382                    25.72          48.95       835.00000          248.37
# 383                    48.40          97.93       969.08334          266.27
# 384                    31.83          56.45       951.58334          306.32
# 385                    52.77          51.45       416.00000          246.35
# 386                    52.83          49.43       388.00000          238.30
#
# sleep_metric  timeNightRem  timeSleepAwake  wakeupsOver15Minutes
# 98                  127.92           37.95                   0.0
# 99                  110.37           49.42                   0.0
# 100                  89.87           69.38                   2.0
# 101                  88.88           51.87                   0.0
# 102                 103.90           31.45                   0.0
# ..                     ...             ...                   ...
# 382                  52.47           25.45                   0.0
# 383                 103.40           47.88                   0.0
# 384                  96.40           31.43                   0.0
# 385                  65.43           52.45                   2.0
# 386                  47.43           52.38                   0.0
#
# [249 rows x 20 columns]

# %%
# Grouping by day
daily_avg = filtered_df.groupby(pd.Grouper(key='start', freq='D')) \
    .mean() \
    .reset_index()

daily_avg = weekly_avg.dropna()
daily_avg
daily_avg.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Grouping by day
# ----> 2 daily_avg = filtered_df.groupby(pd.Grouper(key='start', freq='D')) \
#       3     .mean() \
#       4     .reset_index()
#       6 daily_avg = weekly_avg.dropna()
#       7 daily_avg
#
# NameError: name 'filtered_df' is not defined

# %%
    
    
import pandas as pd
import numpy as np
import random
import secrets
from datetime import datetime
import matplotlib.pyplot as plt

# Loading in data
metrics = pd.read_csv("sleep_metrics.csv")
raw = pd.read_csv("raw_sleep.csv")

    
merged = pd.merge(raw, metrics, on='sleep_session_id', how='inner')
merged = merged.drop(['id', 'timezone', 'log_method', 'user_id', 'end', 'stage'], axis=1)
merged['start'] = pd.to_datetime(merged['start'])
merged['start'] = merged['start'].dt.date
merged = merged.dropna().drop_duplicates()

merged['start'] = pd.to_datetime(merged['start'])
merged['start'] = merged['start'].dt.date
merged = merged.dropna().drop_duplicates()

print("Shape of DataFrame:", merged.shape)
print("\nColumn names:")
print(merged.columns.tolist())
print("\nData types:")
print(merged.dtypes)
# Out:
# Shape of DataFrame: (11568, 4)
#
# Column names:
# ['start', 'sleep_session_id', 'sleep_metric', 'value']
#
# Data types:
# start                object
# sleep_session_id     object
# sleep_metric         object
# value               float64
# dtype: object

# %%
merged
# Out:
#              start                      sleep_session_id  \
# 0       2024-03-14  e851574a-5204-46b3-9b0e-6c5e1cf19131
# 1       2024-03-14  e851574a-5204-46b3-9b0e-6c5e1cf19131
# 2       2024-03-14  e851574a-5204-46b3-9b0e-6c5e1cf19131
# 3       2024-03-14  e851574a-5204-46b3-9b0e-6c5e1cf19131
# 4       2024-03-14  e851574a-5204-46b3-9b0e-6c5e1cf19131
# ...            ...                                   ...
# 405614  2024-04-07  e2fc45f0-fbc5-44af-af88-7df3d82d14c6
# 405615  2024-04-07  e2fc45f0-fbc5-44af-af88-7df3d82d14c6
# 405616  2024-04-07  e2fc45f0-fbc5-44af-af88-7df3d82d14c6
# 405617  2024-04-07  e2fc45f0-fbc5-44af-af88-7df3d82d14c6
# 405618  2024-04-07  e2fc45f0-fbc5-44af-af88-7df3d82d14c6
#
#                 sleep_metric      value
# 0             timeNightInBed  546.50000
# 1               sleepLatency    0.00000
# 2            timeNightAsleep  711.00000
# 3            sleepEfficiency  130.10065
# 4             timeNightAwake -164.50000
# ...                      ...        ...
# 405614  percentageSleepLight   62.77000
# 405615  percentageNightAwake    4.68000
# 405616   percentageNightDeep   16.71000
# 405617    percentageNightRem   16.99000
# 405618  percentageNightLight   61.62000
#
# [11568 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import random
import secrets
from datetime import datetime
import matplotlib.pyplot as plt

# Loading in data
metrics = pd.read_csv("sleep_metrics.csv")
raw = pd.read_csv("raw_sleep.csv")

# Removes outliers for a specific column
def removeOutliers(dataframe, column):
        # Calculate mean and standard deviation of sleepLatency
        mean_sleep_latency = dataframe[column].mean()
        std_sleep_latency = dataframe[column].std()

        # Define the upper and lower bounds for outliers
        upper_bound = mean_sleep_latency + 1.5 * std_sleep_latency
        lower_bound = mean_sleep_latency - 1.5 * std_sleep_latency

        # Filter the DataFrame to remove outliers
        filtered_df = dataframe[(dataframe[column] <= upper_bound) & (dataframe[column] >= lower_bound)]
        filtered_df.loc[:, 'start'] = pd.to_datetime(filtered_df['start'])
        return filtered_df
    
# Merging and cleaning
merged = pd.merge(raw, metrics, on='sleep_session_id', how='inner')
merged = merged.drop(['id', 'timezone', 'log_method', 'user_id', 'end', 'stage'], axis=1)
merged['start'] = pd.to_datetime(merged['start'])
merged['start'] = merged['start'].dt.date
merged = merged.dropna().drop_duplicates()

merged['start'] = pd.to_datetime(merged['start'])
merged['start'] = merged['start'].dt.date
merged = merged.dropna().drop_duplicates()

# Pivoting to relevant columns
df = merged.pivot_table(index='start', columns='sleep_metric', values='value', aggfunc='sum').reset_index().dropna()
df['start'] = pd.to_datetime(df['start'])

# Removing outliers from all columns

# Storing dataframe in DynamoDB
df
